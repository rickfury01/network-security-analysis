# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
df = pd.read_csv('/home/abhinav-biswas/Downloads/data_project/Fuzzing/Fuzzing_labels.csv',header=None,low_memory=False)

# %%
print(df.head(20))
# Out:
#        0  1
# 0    NaN  x
# 1    1.0  0
# 2    2.0  0
# 3    3.0  0
# 4    4.0  0
# 5    5.0  0
# 6    6.0  0
# 7    7.0  0
# 8    8.0  0
# 9    9.0  0
# 10  10.0  0
# 11  11.0  0
# 12  12.0  0
# 13  13.0  0
# 14  14.0  0
# 15  15.0  0
# 16  16.0  0
# 17  17.0  0
# 18  18.0  0
# 19  19.0  0

# %%
print(df.shape)
# Out:
# (2244139, 115)

# %%
print(df.describe())
# Out:
#                 0             1             2             3             4    \
# count  2.244139e+06  2.244139e+06  2.244139e+06  2.244139e+06  2.244139e+06
# mean   1.639905e+02  1.217468e+03  1.509625e+05  2.692612e+02  1.218493e+03
# std    4.807284e+01  3.367412e+02  5.176440e+04  7.149758e+01  3.368590e+02
# min    1.000000e+00  6.000000e+01  0.000000e+00  1.000000e+00  6.000000e+01
# 25%    1.512130e+02  1.290959e+03  1.340687e+05  2.624207e+02  1.293890e+03
# 50%    1.658361e+02  1.312229e+03  1.571441e+05  2.793451e+02  1.310474e+03
# 75%    1.908952e+02  1.333739e+03  1.843591e+05  3.065749e+02  1.335856e+03
# max    2.645009e+02  1.384794e+03  4.257553e+05  3.787117e+02  1.373137e+03
#
#                 5             6             7             8             9    \
# count  2.244139e+06  2.244139e+06  2.244139e+06  2.244139e+06  2.244139e+06
# mean   1.499131e+05  7.998468e+02  1.219556e+03  1.487974e+05  7.924685e+03
# ...
